# %%
# !pip3 install pandas
# !pip3 install openpyxl
# Out:
# Requirement already satisfied: pandas in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: openpyxl in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /Users/sborda/opt/anaconda3/lib/python3.8/site-packages (from openpyxl) (1.0.1)

# %%
import pandas as pd
url = 'https://www.fulcrum.org/downloads/b8515n388?locale=en'
#path = ('...\\filename.xlsx')
xl = pd.ExcelFile(url)
print(xl.sheet_names)
shName = xl.sheet_names
# Out:
# ['Table 9']

# %%
df = pd.read_excel(url, shName[0])
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 500)
display(df)
# Out:
# /Users/sborda/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#              Phase 2      Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0            ELEMENT  SUS DOMESTICUS        NaN        NaN  OVIS VEL CAPRA
# 1                NaN              NR        NME        NMI              NR
# 2               Horn             NaN        NaN        NaN             NaN
# 3        Cranium 1/2              13          3          3             NaN
# 4        Maxilla 1/2               2          2          2               2
# 5       Mandible 1/2              12          6          5               1
# 6              Teeth              19         14          7               8
# 7              Hyoid             NaN        NaN        NaN               1
# 8              Atlas             NaN        NaN        NaN             NaN
# 9               Axis             NaN        NaN        NaN             NaN
# 10       Cerv.Vert.              NaN        NaN        NaN               2
# 11        Tor.Vert.              NaN        NaN        NaN               4
# 12       Lumb.Vert.              NaN        NaN        NaN               8
# 13       Sacr.Vert.              NaN        NaN        NaN             NaN
# 14       Caud. Vert.             NaN        NaN        NaN               1
# 15          Vertebra             NaN        NaN        NaN               1
# 16               Rib              15          9          4              52
# 17           Scapula               3          2          2               3
# 18           Humerus               3          3          3               5
# 19            Radius              11          9          6               2
# 20              Ulna               3          3          3               1
# 21        Pelvis 1/2               6          5          4               5
# 22             Femur               4          4          4               1
# 23           Patella             NaN        NaN        NaN             NaN
# 24             Tibia               2          1          1               2
# 25  Malleolus/Fibula               4          2          1             NaN
# 26           Carpals             NaN        NaN        NaN               1
# 27        Astragalus               3          3          2               1
# 28         Calcaneum               2          2          2               1
# 29           Tarsals             NaN        NaN        NaN             NaN
# 30       Metacarpals               6          6          4               2
# 31       Metatarsals               5          5          1               3
# 32       Metapodials               9          8          3             NaN
# 33         Phalanx 1               3          3          2               1
# 34         Phalanx 2               2          2          2             NaN
# 35         Phalanx 3               2          2          2             NaN
# 36         Sesamoids             NaN        NaN        NaN             NaN
# 37             Total             129         94        NaN             108
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN  BOS TAURUS        NaN        NaN
# 1         NME        NMI          NR        NME        NMI
# 2         NaN        NaN         NaN        NaN        NaN
# 3         NaN        NaN          10          4          3
# 4           2          2           3          3          2
# 5           1          1           8          3          2
# 6           8          7           7          7          3
# 7           1          1         NaN        NaN        NaN
# 8         NaN        NaN         NaN        NaN        NaN
# 9         NaN        NaN         NaN        NaN        NaN
# 10          2          2           5          3          3
# 11          2          2           7          4          3
# 12          4          4         NaN        NaN        NaN
# 13        NaN        NaN           2          1          1
# 14          1          1         NaN        NaN        NaN
# 15          1          1           3          1          1
# 16         12          6           4          1          1
# 17          3          3           3          3          3
# 18          4          3           3          3          2
# 19          2          2         NaN        NaN        NaN
# 20          1          1           3          3          3
# 21          3          3           5          2          1
# 22          1          1         NaN        NaN        NaN
# 23        NaN        NaN         NaN        NaN        NaN
# 24          2          2           2          1          1
# 25        NaN        NaN         NaN        NaN        NaN
# 26          1          1         NaN        NaN        NaN
# 27          1          1         NaN        NaN        NaN
# 28          1          1         NaN        NaN        NaN
# 29        NaN        NaN         NaN        NaN        NaN
# 30          2          2         NaN        NaN        NaN
# 31          3          3           1          1          1
# 32        NaN        NaN           1          1          1
# 33          1          1         NaN        NaN        NaN
# 34        NaN        NaN           1          1          1
# 35        NaN        NaN         NaN        NaN        NaN
# 36        NaN        NaN         NaN        NaN        NaN
# 37         59        NaN          68         42        NaN
